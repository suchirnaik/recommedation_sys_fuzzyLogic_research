# %%
import pandas as pd
Customer_address = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/Customer_address.csv')

# %%
Customer_demographic = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/Customer_demographic.csv',encoding='latin-1')

# %%
Customer_demographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %%
KPMGtransactions = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/KPMGtransactions.csv')

# %%
New_customers_KPMG = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/New_customers_KPMG.csv')

# %%
New_customers_KPMG.head(1)
# Out:
#   first_name last_name gender  past_3_years_bike_related_purchases  \
# 0    Chickie   Brister   Male                                   86
#
#           DOB        job_title job_industry_category wealth_segment  \
# 0  1957-07-12  General Manager         Manufacturing  Mass Customer
#
#   deceased_indicator owns_car  ...  state    country  property_valuation  \
# 0                  N      Yes  ...    QLD  Australia                 6.0
#
#   Unnamed: 16 Unnamed: 17  Unnamed: 18  Unnamed: 19  Unnamed: 20  Rank  \
# 0        1.07      1.3375     1.671875     1.421094            1     1
#
#      Value
# 0  1.71875
#
# [1 rows x 23 columns]

# %%
KPMGtransactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950          2/25/17        False
# 1               2           3         3120          5/21/17         True
# 2               3          37          402         10/16/17        False
# 3               4          88         3135          8/31/17        False
# 4               5          78          787          10/1/17         True
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#     list_price   standard_cost product_first_sold_date
# ...

# %%
### Checking for missing values

# %%
missing_values_count_KPMGtransactions = KPMGtransactions.isnull().sum()
missing_values_count_KPMGtransactions
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
#   list_price                 0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %%
missing_values_count_Customer_address = Customer_address.isnull().sum()
missing_values_count_Customer_address
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
missing_values_count_Customer_demographic = Customer_demographic.isnull().sum()
missing_values_count_Customer_demographic
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %%
missing_values_count_New_customers_KPMG = New_customers_KPMG.isnull().sum()
missing_values_count_New_customers_KPMG
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Unnamed: 16                              0
# Unnamed: 17                              0
# Unnamed: 18                              0
# Unnamed: 19                              0
# Unnamed: 20                              0
# Rank                                     0
# ...

# %%
### Checking for data types to see if columns have incorrect datatypes

# %%
KPMGtransactions.dtypes
#transaction date  - object to datetime
#list_price -  object to int
#standard cost - object to int
#product_first_sold_date - object to datetime
# Out:
# transaction_id              int64
# product_id                  int64
# customer_id                 int64
# transaction_date           object
# online_order               object
# order_status               object
# brand                      object
# product_line               object
# product_class              object
# product_size               object
#   list_price               object
# standard_cost              object
# product_first_sold_date    object
# dtype: object

# %%
Customer_address.dtypes
# Out:
# customer_id            int64
# address               object
# postcode               int64
# state                 object
# country               object
# property_valuation     int64
# dtype: object

# %%
Customer_demographic.dtypes
#DOB - object to datetime
# Out:
# customer_id                              int64
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# default                                 object
# owns_car                                object
# tenure                                 float64
# dtype: object

# %%
New_customers_KPMG.dtypes
# Out:
# first_name                              object
# last_name                               object
# gender                                  object
# past_3_years_bike_related_purchases      int64
# DOB                                     object
# job_title                               object
# job_industry_category                   object
# wealth_segment                          object
# deceased_indicator                      object
# owns_car                                object
# tenure                                   int64
# address                                 object
# postcode                                 int64
# state                                   object
# country                                 object
# property_valuation                     float64
# Unnamed: 16                            float64
# Unnamed: 17                            float64
# Unnamed: 18                            float64
# Unnamed: 19                            float64
# ...

# %%
### Removing spaces before column names for data wrangling

# %%
#To remove the space between the column list_price
# Get the current column names with spaces
current_column_names = KPMGtransactions.columns

# Remove spaces from column names
new_column_names = [name.replace(' ', '') for name in current_column_names]

# Rename the columns with the new names
KPMGtransactions.rename(columns=dict(zip(current_column_names, new_column_names)), inplace=True)

# %%
###Removing unwanted characters before data for further data wranglng like the dollar sig

# %%
KPMGtransactions['list_price'] = KPMGtransactions['list_price'].str.replace('$', '')
# Out:
# /var/folders/0w/78_w9pm16ts4trsks5rjpd440000gn/T/ipykernel_59239/1357787610.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   KPMGtransactions['list_price'] = KPMGtransactions['list_price'].str.replace('$', '')

# %%
KPMGtransactions['standard_cost'] = KPMGtransactions['standard_cost'].str.replace('$', '')
# Out:
# /var/folders/0w/78_w9pm16ts4trsks5rjpd440000gn/T/ipykernel_59239/4001272511.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   KPMGtransactions['standard_cost'] = KPMGtransactions['standard_cost'].str.replace('$', '')

# %%
#$ removed from list_price and standard_cost
KPMGtransactions.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950          2/25/17        False
#
#   order_status  brand product_line product_class product_size list_price  \
# 0     Approved  Solex     Standard        medium       medium     71.49
#
#   standard_cost product_first_sold_date
# 0         53.62                 12/2/12

# %%
#Removing commas from price for converting to data type float

# %%
import pandas as pd

# Assuming df is your DataFrame and 'column_with_commas' is the column with commas
KPMGtransactions['list_price'] = KPMGtransactions['list_price'].str.replace(',', '')
KPMGtransactions['standard_cost'] = KPMGtransactions['standard_cost'].str.replace(',', '')

# %%
#G. Changing the columns to the correct datatype

# %%
 #KPMGtransactions dataframe

# %%
# List of columns to convert to int
columns_to_convert = ['list_price', 'standard_cost']

# Convert selected columns to int data type
KPMGtransactions[columns_to_convert] = KPMGtransactions[columns_to_convert].astype(float)

# %%
KPMGtransactions['transaction_date'] = pd.to_datetime(KPMGtransactions['transaction_date'])

# %%
KPMGtransactions['product_first_sold_date'] = pd.to_datetime(KPMGtransactions['product_first_sold_date'])

# %%
#All columns changed to the correct data type
KPMGtransactions.dtypes
# Out:
# transaction_id                      int64
# product_id                          int64
# customer_id                         int64
# transaction_date           datetime64[ns]
# online_order                       object
# order_status                       object
# brand                              object
# product_line                       object
# product_class                      object
# product_size                       object
# list_price                        float64
# standard_cost                     float64
# product_first_sold_date    datetime64[ns]
# dtype: object

# %%
KPMGtransactions.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
#
#   order_status  brand product_line product_class product_size  list_price  \
# 0     Approved  Solex     Standard        medium       medium       71.49
#
#    standard_cost product_first_sold_date
# 0          53.62              2012-12-02

# %%
#b.Customer_demographic dataframe

# %%
Customer_demographic['DOB'] = pd.to_datetime(Customer_demographic['DOB'])

# %%
Customer_demographic.dtypes
# Out:
# customer_id                                     int64
# first_name                                     object
# last_name                                      object
# gender                                         object
# past_3_years_bike_related_purchases             int64
# DOB                                    datetime64[ns]
# job_title                                      object
# job_industry_category                          object
# wealth_segment                                 object
# deceased_indicator                             object
# default                                        object
# owns_car                                       object
# tenure                                        float64
# dtype: object

# %%
Customer_address
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %%
KPMGtransactions
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
New_customers_KPMG
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0      Chickie    Brister    Male                                   86
# 1        Morly     Genery    Male                                   69
# 2      Ardelis  Forrester  Female                                   10
# 3       Lucine      Stutt  Female                                   64
# 4      Melinda     Hadlee  Female                                   34
# ..         ...        ...     ...                                  ...
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# ...

# %%
Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %%
### Gender preprocessing

# %%
Customer_demographic['gender'] = Customer_demographic['gender'].replace({'F': 'Female', 'Femal': 'Female','M':'Male'})

# %%
Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %%
import matplotlib.pyplot as plt
# Count the occurrences of each value in the 'gender' column
value_counts = Customer_demographic['gender'].value_counts()

# Create a bar chart with correct x-axis labels
plt.bar(value_counts.index, value_counts.values)

# Set the x-axis labels
plt.xticks(value_counts.index, value_counts.index)

# Add labels and title
plt.xlabel('gender')
plt.ylabel('Count')
plt.title('Bar Chart of Customer_demographic')

# Show the plot
plt.show()

# %%
### Age  preprocessing

# %%
latest_date = KPMGtransactions['transaction_date'].max()
latest_date
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
Customer_demographic['Age'] = (latest_date - Customer_demographic['DOB']).dt.days // 365

# %%
Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %%
def convert_negative_age(age):
    return max(age, 0)

# Apply the function to the 'Age' column
Customer_demographic['Age'] = Customer_demographic['Age'].apply(convert_negative_age)

Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %% [markdown]
# ### Fuzzy memebership functions

# %%
#Importing job_title score from eda for aiding to the fuzzy logic creation

# %%
job_title_score = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/job_title _score.csv')

# %%
job_title_score
# Out:
#      index                    job_title  transaction_count  jobtitle_score
# 0       81                 Geologist IV           3.714286               2
# 1      121         Programmer Analyst I           4.200000               3
# 2        3    Account Representative II           4.250000               4
# 3      144         Safety Technician IV           4.333333               5
# 4      187               Web Designer I           4.333333               5
# ..     ...                          ...                ...             ...
# 190     10       Accounting Assistant I           7.875000             133
# 191     16  Administrative Assistant II           8.000000             134
# 192     83               Health Coach I           9.000000             135
# 193    124        Programmer Analyst IV           9.000000             135
# 194    194             Web Developer IV           9.000000             135
#
# [195 rows x 4 columns]

# %%
job_title_score_2 = job_title_score.rename(columns={'transaction_count': 'job_title_transaction_count'})
columns_to_drop = ['index','jobtitle_score']
job_title_score_2 = job_title_score_2.drop(columns=columns_to_drop)

# %%
job_title_score_2
# Out:
#                        job_title  job_title_transaction_count
# 0                   Geologist IV                     3.714286
# 1           Programmer Analyst I                     4.200000
# 2      Account Representative II                     4.250000
# 3           Safety Technician IV                     4.333333
# 4                 Web Designer I                     4.333333
# ..                           ...                          ...
# 190       Accounting Assistant I                     7.875000
# 191  Administrative Assistant II                     8.000000
# 192               Health Coach I                     9.000000
# 193        Programmer Analyst IV                     9.000000
# 194             Web Developer IV                     9.000000
#
# [195 rows x 2 columns]

# %%
unique_count = KPMGtransactions['brand'].nunique()

# %%
unique_count
# Out:
# 6

# %%
### Joining the tables to craete a master table

# %%
postcode_score = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/postcode_score.csv')

# %%
postcode_score
# Out:
#      postcode  transaction_count  customer_id  postcode_score
# 0      3194.0                1.0            1               2
# 1      3818.0                1.0            1               2
# 2      3616.0                1.0            1               2
# 3      2850.0                1.0            1               2
# 4      4159.0                1.0            1               2
# ..        ...                ...          ...             ...
# 830    2292.0               10.0            1             133
# 831    3940.0               11.0            1             134
# 832    4568.0               11.0            1             134
# 833    2265.0               11.5            2             135
# 834    3400.0               12.0            1             136
#
# [835 rows x 4 columns]

# %%
postcode_score_2 = postcode_score.rename(columns={'transaction_count': 'postcode_transaction_count'})

# %%
postcode_score_2
# Out:
#      postcode  postcode_transaction_count  customer_id  postcode_score
# 0      3194.0                         1.0            1               2
# 1      3818.0                         1.0            1               2
# 2      3616.0                         1.0            1               2
# 3      2850.0                         1.0            1               2
# 4      4159.0                         1.0            1               2
# ..        ...                         ...          ...             ...
# 830    2292.0                        10.0            1             133
# 831    3940.0                        11.0            1             134
# 832    4568.0                        11.0            1             134
# 833    2265.0                        11.5            2             135
# 834    3400.0                        12.0            1             136
#
# [835 rows x 4 columns]

# %%
columns_to_drop = ['customer_id', 'postcode_score']
postcode_score_2 = postcode_score_2.drop(columns=columns_to_drop)

# %%
postcode_score_2
# Out:
#      postcode  postcode_transaction_count
# 0      3194.0                         1.0
# 1      3818.0                         1.0
# 2      3616.0                         1.0
# 3      2850.0                         1.0
# 4      4159.0                         1.0
# ..        ...                         ...
# 830    2292.0                        10.0
# 831    3940.0                        11.0
# 832    4568.0                        11.0
# 833    2265.0                        11.5
# 834    3400.0                        12.0
#
# [835 rows x 2 columns]

# %% [markdown]
# ## Import score table for age

# %%
age_score = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/age_score.csv')

# %%
age_score
# Out:
#       Age  transaction_count  age_score
# 0    15.0           4.600000          2
# 1    45.0           5.000000          3
# 2    24.0           5.320755          4
# 3    17.0           5.358974          5
# 4    25.0           5.437500          6
# 5    26.0           5.452381          7
# 6    29.0           5.454545          8
# 7    31.0           5.479592          9
# 8    23.0           5.538462         10
# 9    44.0           5.544643         11
# 10   37.0           5.545455         12
# 11   34.0           5.548387         13
# 12   18.0           5.576923         14
# 13   32.0           5.580247         15
# 14   35.0           5.583333         16
# 15   43.0           5.610687         17
# 16   20.0           5.633333         18
# 17   27.0           5.634146         19
# 18   19.0           5.647887         20
# 19   30.0           5.651515         21
# 20   38.0           5.722222         22
# 21    0.0           5.730803         23
# ...

# %%
age_score_2 = age_score.rename(columns={'transaction_count': 'age_transaction_count'})
columns_to_drop = ['age_score']
age_score_2 = age_score_2.drop(columns=columns_to_drop)

# %%
age_score_2
# Out:
#       Age  age_transaction_count
# 0    15.0               4.600000
# 1    45.0               5.000000
# 2    24.0               5.320755
# 3    17.0               5.358974
# 4    25.0               5.437500
# 5    26.0               5.452381
# 6    29.0               5.454545
# 7    31.0               5.479592
# 8    23.0               5.538462
# 9    44.0               5.544643
# 10   37.0               5.545455
# 11   34.0               5.548387
# 12   18.0               5.576923
# 13   32.0               5.580247
# 14   35.0               5.583333
# 15   43.0               5.610687
# 16   20.0               5.633333
# 17   27.0               5.634146
# 18   19.0               5.647887
# 19   30.0               5.651515
# 20   38.0               5.722222
# 21    0.0               5.730803
# 22   33.0               5.750000
# 23   41.0               5.782609
# 24   42.0               5.783505
# 25   16.0               5.793103
# 26   40.0               5.849162
# ...

# %% [markdown]
# #### Importing score table for tenure

# %%
tenure_score = pd.read_csv('/Users/suchirnaik/Downloads/KPMG/tenure_score.csv')

# %%
tenure_score
# Out:
#     tenure  transaction_count
# 0     22.0           5.312500
# 1     18.0           5.480000
# 2      4.0           5.529762
# 3     10.0           5.564972
# 4     14.0           5.568306
# 5      8.0           5.608696
# 6      5.0           5.620513
# 7     13.0           5.624277
# 8     11.0           5.649485
# 9     20.0           5.659091
# 10     2.0           5.661538
# 11    16.0           5.675532
# 12     9.0           5.718391
# 13     3.0           5.767606
# 14    21.0           5.851064
# 15     7.0           5.862069
# 16     1.0           5.879195
# 17     6.0           5.882716
# 18    17.0           5.933735
# 19    12.0           5.955056
# 20    19.0           5.978571
# 21    15.0           5.986928

# %%
tenure_score_2 = tenure_score.rename(columns={'transaction_count': 'tenure_transaction_count'})

# %%
tenure_score_2.head()
# Out:
#    tenure  tenure_transaction_count
# 0    22.0                  5.312500
# 1    18.0                  5.480000
# 2     4.0                  5.529762
# 3    10.0                  5.564972
# 4    14.0                  5.568306

# %% [markdown]
# ##### Creating the master table for establishing the relationships, one hot encoding and the membership functions

# %%
Customer_demographic
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp  Female
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                      93 2053-10-12     Executive Secretary
# 1                                      81 1980-12-16  Administrative Officer
# 2                                      61 2054-01-20      Recruiting Manager
# ...

# %%
Customer_demographic_join = Customer_demographic[['customer_id','gender','job_title','wealth_segment','deceased_indicator','owns_car','tenure','Age']]

# %%
Customer_demographic_join
# Out:
#       customer_id  gender               job_title     wealth_segment  \
# 0               1  Female     Executive Secretary      Mass Customer
# 1               2    Male  Administrative Officer      Mass Customer
# 2               3    Male      Recruiting Manager      Mass Customer
# 3               4    Male                     NaN      Mass Customer
# 4               5  Female           Senior Editor  Affluent Customer
# ...           ...     ...                     ...                ...
# 3995         3996  Female   VP Product Management      Mass Customer
# 3996         3997  Female         Statistician II     High Net Worth
# 3997         3998       U       Assistant Manager     High Net Worth
# 3998         3999    Male                     NaN  Affluent Customer
# 3999         4000    Male    Software Engineer IV  Affluent Customer
#
#      deceased_indicator owns_car  tenure   Age
# 0                     N      Yes    11.0   0.0
# ...

# %%
Customer_demographic_join = Customer_demographic_join.fillna('Missing')

# %%
Customer_address
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %%
Customer_address_join = Customer_address[['customer_id','postcode']]

# %%
Customer_address_join
# Out:
#       customer_id  postcode
# 0               1      2016
# 1               2      2153
# 2               4      4211
# 3               5      2448
# 4               6      3216
# ...           ...       ...
# 3994         3999      3064
# 3995         4000      4511
# 3996         4001      2756
# 3997         4002      4032
# 3998         4003      2251
#
# [3999 rows x 2 columns]

# %%
Customer_demographic_join['gender'].nunique()

# %%
Customer_demographic_join

# %%
Customer_demographic_join['gender'].isna().sum()

# %%
 Customer_demographic['gender'].value_counts()

# %%
Customer_demographic_join.head(1)
# Out:
#    customer_id  gender            job_title wealth_segment deceased_indicator  \
# 0            1  Female  Executive Secretary  Mass Customer                  N
#
#   owns_car tenure  Age
# 0      Yes   11.0  0.0

# %% [markdown]
# ### Creating the master table

# %%
join_1 = pd.merge(KPMGtransactions, Customer_demographic_join, how='left', on='customer_id')

# %%
join_1
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
Customer_address_join.head(1)
# Out:
#    customer_id  postcode
# 0            1      2016

# %%
join_2 = pd.merge(join_1, Customer_address_join, how='left', on='customer_id')

# %%
job_title_score_2.head()
# Out:
#                    job_title  job_title_transaction_count
# 0               Geologist IV                     3.714286
# 1       Programmer Analyst I                     4.200000
# 2  Account Representative II                     4.250000
# 3       Safety Technician IV                     4.333333
# 4             Web Designer I                     4.333333

# %%
join_3 = pd.merge(join_2, job_title_score_2, how='left', on='job_title')

# %%
postcode_score_2.head(1)
# Out:
#    postcode  postcode_transaction_count
# 0    3194.0                         1.0

# %%
join_4 = pd.merge(join_3, postcode_score_2, how='left', on='postcode')

# %%
 join_4.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
#
#   order_status  brand product_line product_class product_size  ...  gender  \
# 0     Approved  Solex     Standard        medium       medium  ...    Male
#
#              job_title wealth_segment deceased_indicator owns_car tenure  Age  \
# 0  Software Engineer I  Mass Customer                  N      Yes   10.0  0.0
#
#   postcode job_title_transaction_count postcode_transaction_count
# 0   3064.0                    5.833333                        5.0
#
# [1 rows x 23 columns]

# %%
age_score_2.dtypes
# Out:
# Age                      float64
# age_transaction_count    float64
# dtype: object

# %%
join_4.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                 object
# Age                                    object
# ...

# %%
join_4['Age'].isnull().sum()
# Out:
# 0

# %%
join_4['Age'].value_counts()
# Out:
# 0.0        6496
# 39.0       1112
# 40.0       1047
# 41.0        798
# 43.0        735
# 44.0        621
# 38.0        618
# 37.0        610
# 42.0        561
# 31.0        537
# 22.0        532
# 32.0        452
# Missing     446
# 28.0        417
# 36.0        411
# 19.0        401
# 21.0        401
# 30.0        373
# 23.0        360
# 29.0        360
# 25.0        348
# 20.0        338
# 18.0        290
# 24.0        282
# 27.0        231
# 26.0        229
# 17.0        209
# 33.0        207
# 35.0        201
# 34.0        172
# 16.0        168
# 15.0         23
# 174.0         9
# 45.0          5
# Name: Age, dtype: int64

# %%
join_4['Age'] = join_4['Age'].replace(to_replace="Missing",value="0")

# %%
join_4['Age'].value_counts()
# Out:
# 0.0      6496
# 39.0     1112
# 40.0     1047
# 41.0      798
# 43.0      735
# 44.0      621
# 38.0      618
# 37.0      610
# 42.0      561
# 31.0      537
# 22.0      532
# 32.0      452
# 0         446
# 28.0      417
# 36.0      411
# 19.0      401
# 21.0      401
# 30.0      373
# 23.0      360
# 29.0      360
# 25.0      348
# 20.0      338
# 18.0      290
# 24.0      282
# 27.0      231
# 26.0      229
# 17.0      209
# 33.0      207
# 35.0      201
# 34.0      172
# 16.0      168
# 15.0       23
# 174.0       9
# 45.0        5
# Name: Age, dtype: int64

# %%
join_4["Age"] = join_4["Age"].fillna(0)

# %%
join_4.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                 object
# Age                                    object
# ...

# %%
join_4['Age'] = join_4['Age'].astype(float)

# %%
join_5 = pd.merge(join_4, age_score_2, how='left', on='Age')

# %%
join_5.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                 object
# Age                                   float64
# ...

# %%
join_5.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
# 1               2           3         3120       2017-05-21         True
# 2               3          37          402       2017-10-16        False
# 3               4          88         3135       2017-08-31        False
# 4               5          78          787       2017-10-01         True
#
#   order_status           brand product_line product_class product_size  ...  \
# 0     Approved           Solex     Standard        medium       medium  ...
# 1     Approved   Trek Bicycles     Standard        medium        large  ...
# 2     Approved      OHM Cycles     Standard           low       medium  ...
# 3     Approved  Norco Bicycles     Standard        medium       medium  ...
# 4     Approved  Giant Bicycles     Standard        medium        large  ...
#
# ...

# %%
#checking for consistency of join
join_5['tenure'].unique()
# Out:
# array([10.0, 22.0, 16.0, 2.0, 12.0, 18.0, 6.0, 7.0, 8.0, 13.0, 'Missing',
#        19.0, 4.0, 3.0, 9.0, 15.0, 17.0, 1.0, 20.0, 11.0, 21.0, 5.0, 14.0,
#        nan], dtype=object)

# %%
value_to_count = 'Missing'
count = (join_5['tenure'] == value_to_count).sum()
count
# Out:
# 446

# %%
join_5['tenure'] = join_5['tenure'].replace('Missing', '0.0')

# %%
join_5['tenure'].unique()
# Out:
# array([10.0, 22.0, 16.0, 2.0, 12.0, 18.0, 6.0, 7.0, 8.0, 13.0, '0.0',
#        19.0, 4.0, 3.0, 9.0, 15.0, 17.0, 1.0, 20.0, 11.0, 21.0, 5.0, 14.0,
#        nan], dtype=object)

# %%
join_5['tenure'] = join_5['tenure'].fillna('0.0')

# %%
join_5['tenure'].unique()
# Out:
# array([10.0, 22.0, 16.0, 2.0, 12.0, 18.0, 6.0, 7.0, 8.0, 13.0, '0.0',
#        19.0, 4.0, 3.0, 9.0, 15.0, 17.0, 1.0, 20.0, 11.0, 21.0, 5.0, 14.0],
#       dtype=object)

# %%
join_5['tenure'] = join_5['tenure'].astype(float)

# %%
join_5.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                float64
# Age                                   float64
# ...

# %%
tenure_score_2['tenure'].unique()
# Out:
# array([22., 18.,  4., 10., 14.,  8.,  5., 13., 11., 20.,  2., 16.,  9.,
#         3., 21.,  7.,  1.,  6., 17., 12., 19., 15.])

# %%
tenure_score_2
# Out:
#     tenure  tenure_transaction_count
# 0     22.0                  5.312500
# 1     18.0                  5.480000
# 2      4.0                  5.529762
# 3     10.0                  5.564972
# 4     14.0                  5.568306
# 5      8.0                  5.608696
# 6      5.0                  5.620513
# 7     13.0                  5.624277
# 8     11.0                  5.649485
# 9     20.0                  5.659091
# 10     2.0                  5.661538
# 11    16.0                  5.675532
# 12     9.0                  5.718391
# 13     3.0                  5.767606
# 14    21.0                  5.851064
# 15     7.0                  5.862069
# 16     1.0                  5.879195
# 17     6.0                  5.882716
# 18    17.0                  5.933735
# 19    12.0                  5.955056
# 20    19.0                  5.978571
# 21    15.0                  5.986928

# %%
tenure_score_2.dtypes
# Out:
# tenure                      float64
# tenure_transaction_count    float64
# dtype: object

# %%
mean_value = tenure_score_2['tenure_transaction_count'].mean()
mean_value
# Out:
# 5.716818272031091

# %%
#Adding a new row woth tenure 0 and mean value to help with join 
new_row = {'tenure': 0.0, 'tenure_transaction_count':5.716818 }
tenure_score_2 = tenure_score_2.append(new_row, ignore_index=True)
# Out:
# /var/folders/0w/78_w9pm16ts4trsks5rjpd440000gn/T/ipykernel_59239/1998102627.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   tenure_score_2 = tenure_score_2.append(new_row, ignore_index=True)

# %%
tenure_score_2
# Out:
#     tenure  tenure_transaction_count
# 0     22.0                  5.312500
# 1     18.0                  5.480000
# 2      4.0                  5.529762
# 3     10.0                  5.564972
# 4     14.0                  5.568306
# 5      8.0                  5.608696
# 6      5.0                  5.620513
# 7     13.0                  5.624277
# 8     11.0                  5.649485
# 9     20.0                  5.659091
# 10     2.0                  5.661538
# 11    16.0                  5.675532
# 12     9.0                  5.718391
# 13     3.0                  5.767606
# 14    21.0                  5.851064
# 15     7.0                  5.862069
# 16     1.0                  5.879195
# 17     6.0                  5.882716
# 18    17.0                  5.933735
# 19    12.0                  5.955056
# 20    19.0                  5.978571
# 21    15.0                  5.986928
# 22     0.0                  5.716818

# %%
join_6 = pd.merge(join_5, tenure_score_2, how='left', on='tenure')

# %%
join_6
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
join_6.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                float64
# Age                                   float64
# ...

# %% [markdown]
# #### Creating three new features Recency , Frequenbcyu and Monetary value for each of the customers

# %%
join_6
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
latest_transaction_dates = join_6.groupby('customer_id')['transaction_date'].max().reset_index()

# %%
latest_transaction_dates
# Out:
#       customer_id transaction_date
# 0               1       2017-12-23
# 1               2       2017-08-24
# 2               3       2017-09-19
# 3               4       2017-06-18
# 4               5       2017-12-14
# ...           ...              ...
# 3489         3497       2017-11-08
# 3490         3498       2017-08-25
# 3491         3499       2017-11-09
# 3492         3500       2017-08-08
# 3493         5034       2017-10-07
#
# [3494 rows x 2 columns]

# %%
max_date  = join_6['transaction_date'].max()

# %%
latest_transaction_dates['recency'] = (max_date - latest_transaction_dates['transaction_date'] ).dt.days

# %%
latest_transaction_dates
# Out:
#       customer_id transaction_date  recency
# 0               1       2017-12-23        7
# 1               2       2017-08-24      128
# 2               3       2017-09-19      102
# 3               4       2017-06-18      195
# 4               5       2017-12-14       16
# ...           ...              ...      ...
# 3489         3497       2017-11-08       52
# 3490         3498       2017-08-25      127
# 3491         3499       2017-11-09       51
# 3492         3500       2017-08-08      144
# 3493         5034       2017-10-07       84
#
# [3494 rows x 3 columns]

# %%
#checking if negative values are present
(latest_transaction_dates['recency'] < 0).any()
# Out:
# False

# %%
latest_transaction_dates.drop('transaction_date', axis=1, inplace=True)

# %%
latest_transaction_dates
# Out:
#       customer_id  recency
# 0               1        7
# 1               2      128
# 2               3      102
# 3               4      195
# 4               5       16
# ...           ...      ...
# 3489         3497       52
# 3490         3498      127
# 3491         3499       51
# 3492         3500      144
# 3493         5034       84
#
# [3494 rows x 2 columns]

# %%
join_7 = pd.merge(join_6, latest_transaction_dates, how='left', on='customer_id')

# %%
join_7
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
## Frequency

# %%
frequency_transactions = join_7.groupby('customer_id')['transaction_date'].count().reset_index()

# %%
frequency_transactions
# Out:
#       customer_id  transaction_date
# 0               1                11
# 1               2                 3
# 2               3                 8
# 3               4                 2
# 4               5                 6
# ...           ...               ...
# 3489         3497                 3
# 3490         3498                 6
# 3491         3499                 7
# 3492         3500                 6
# 3493         5034                 3
#
# [3494 rows x 2 columns]

# %%
frequency_transactions = frequency_transactions.rename(columns={'transaction_date': 'frequency'})

# %%
frequency_transactions
# Out:
#       customer_id  frequency
# 0               1         11
# 1               2          3
# 2               3          8
# 3               4          2
# 4               5          6
# ...           ...        ...
# 3489         3497          3
# 3490         3498          6
# 3491         3499          7
# 3492         3500          6
# 3493         5034          3
#
# [3494 rows x 2 columns]

# %%
join_8 = pd.merge(join_7, frequency_transactions, how='left', on='customer_id')

# %%
join_8.head(1)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       2017-02-25        False
#
#   order_status  brand product_line product_class product_size  ...  owns_car  \
# 0     Approved  Solex     Standard        medium       medium  ...       Yes
#
#    tenure  Age postcode job_title_transaction_count  \
# 0    10.0  0.0   3064.0                    5.833333
#
#   postcode_transaction_count age_transaction_count tenure_transaction_count  \
# 0                        5.0              5.730803                 5.564972
#
#    recency  frequency
# 0       75          3
#
# [1 rows x 27 columns]

# %%
join_8.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                float64
# Age                                   float64
# ...

# %%
monetary_value = join_8.groupby('customer_id')['list_price'].sum().reset_index()

# %%
monetary_value
# Out:
#       customer_id  list_price
# 0               1     9084.45
# 1               2     4149.07
# 2               3     9888.23
# 3               4     1047.72
# 4               5     5903.20
# ...           ...         ...
# 3489         3497     3744.07
# 3490         3498     5177.06
# 3491         3499     7673.48
# 3492         3500     4922.41
# 3493         5034     1519.92
#
# [3494 rows x 2 columns]

# %%
monetary_value = monetary_value.rename(columns = {'list_price':'total_monetary_value'})

# %%
monetary_value
# Out:
#       customer_id  total_monetary_value
# 0               1               9084.45
# 1               2               4149.07
# 2               3               9888.23
# 3               4               1047.72
# 4               5               5903.20
# ...           ...                   ...
# 3489         3497               3744.07
# 3490         3498               5177.06
# 3491         3499               7673.48
# 3492         3500               4922.41
# 3493         5034               1519.92
#
# [3494 rows x 2 columns]

# %%
join_9 = pd.merge(join_8, monetary_value, how='left', on='customer_id')

# %%
join_9
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 4                   5          78          787       2017-10-01         True
# ...               ...         ...          ...              ...          ...
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19998           19999           6         2764       2017-07-03        False
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
join_9.dtypes
# Out:
# transaction_id                          int64
# product_id                              int64
# customer_id                             int64
# transaction_date               datetime64[ns]
# online_order                           object
# order_status                           object
# brand                                  object
# product_line                           object
# product_class                          object
# product_size                           object
# list_price                            float64
# standard_cost                         float64
# product_first_sold_date        datetime64[ns]
# gender                                 object
# job_title                              object
# wealth_segment                         object
# deceased_indicator                     object
# owns_car                               object
# tenure                                float64
# Age                                   float64
# ...

# %%
join_9.isna().any()
# Out:
# transaction_id                 False
# product_id                     False
# customer_id                    False
# transaction_date               False
# online_order                    True
# order_status                   False
# brand                           True
# product_line                    True
# product_class                   True
# product_size                    True
# list_price                     False
# standard_cost                   True
# product_first_sold_date         True
# gender                          True
# job_title                       True
# wealth_segment                  True
# deceased_indicator              True
# owns_car                        True
# tenure                         False
# Age                            False
# postcode                        True
# job_title_transaction_count     True
# postcode_transaction_count      True
# age_transaction_count          False
# tenure_transaction_count       False
# ...

# %%
join_9['brand'].unique()
# Out:
# array(['Solex', 'Trek Bicycles', 'OHM Cycles', 'Norco Bicycles',
#        'Giant Bicycles', 'WeareA2B', nan], dtype=object)

# %%
join_9.dropna(subset=['brand'], inplace=True)

# %%
join_9.isna().any()
# Out:
# transaction_id                 False
# product_id                     False
# customer_id                    False
# transaction_date               False
# online_order                    True
# order_status                   False
# brand                          False
# product_line                   False
# product_class                  False
# product_size                   False
# list_price                     False
# standard_cost                  False
# product_first_sold_date        False
# gender                          True
# job_title                       True
# wealth_segment                  True
# deceased_indicator              True
# owns_car                        True
# tenure                         False
# Age                            False
# postcode                        True
# job_title_transaction_count     True
# postcode_transaction_count      True
# age_transaction_count          False
# tenure_transaction_count       False
# ...

# %%
master_table  = join_9.dropna()

# %%
join_9
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 5                   6          25         2339       2017-03-08         True
# ...               ...         ...          ...              ...          ...
# 19994           19995           9          718       2017-05-13         True
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
master_table
# Out:
#        transaction_id  product_id  customer_id transaction_date online_order  \
# 0                   1           2         2950       2017-02-25        False
# 1                   2           3         3120       2017-05-21         True
# 2                   3          37          402       2017-10-16        False
# 3                   4          88         3135       2017-08-31        False
# 5                   6          25         2339       2017-03-08         True
# ...               ...         ...          ...              ...          ...
# 19994           19995           9          718       2017-05-13         True
# 19995           19996          51         1018       2017-06-24         True
# 19996           19997          41          127       2017-11-09         True
# 19997           19998          87         2284       2017-04-14         True
# 19999           20000          11         1144       2017-09-22         True
#
# ...

# %%
master_table.isna().any()
# Out:
# transaction_id                 False
# product_id                     False
# customer_id                    False
# transaction_date               False
# online_order                   False
# order_status                   False
# brand                          False
# product_line                   False
# product_class                  False
# product_size                   False
# list_price                     False
# standard_cost                  False
# product_first_sold_date        False
# gender                         False
# job_title                      False
# wealth_segment                 False
# deceased_indicator             False
# owns_car                       False
# tenure                         False
# Age                            False
# postcode                       False
# job_title_transaction_count    False
# postcode_transaction_count     False
# age_transaction_count          False
# tenure_transaction_count       False
# ...

# %%
master_table['order_status'].unique()
# Out:
# array(['Approved', 'Cancelled'], dtype=object)

# %%
master_table['product_line'].unique()
# Out:
# array(['Standard', 'Road', 'Touring', 'Mountain'], dtype=object)

# %%
master_table['product_class'].unique()
# Out:
# array(['medium', 'low', 'high'], dtype=object)

# %%
master_table['product_size'].unique()
# Out:
# array(['medium', 'large', 'small'], dtype=object)

# %%
master_table['gender'].unique()
# Out:
# array(['Male', 'Female', 'U'], dtype=object)

# %%
master_table['wealth_segment'].unique()
# Out:
# array(['Mass Customer', 'Affluent Customer', 'High Net Worth'],
#       dtype=object)

# %%
master_table['deceased_indicator'].unique()
# Out:
# array(['N', 'Y'], dtype=object)

# %%
master_table['online_order'].unique()
# Out:
# array([False, True], dtype=object)

# %%
master_table['owns_car'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
downloads_folder = f'/Users/suchirnaik/Downloads/KPMG/'


file_name = 'master_table_for_fuzzy.csv'


file_path = downloads_folder + file_name

master_table.to_csv(file_path, index=False)
